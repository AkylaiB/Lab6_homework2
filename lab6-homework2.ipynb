# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

data = pd.read_csv('../input/heart-disease-prediction-using-logistic-regression/framingham.csv')

# %%
data.columns
# Out:
# Index(['male', 'age', 'education', 'currentSmoker', 'cigsPerDay', 'BPMeds',
#        'prevalentStroke', 'prevalentHyp', 'diabetes', 'totChol', 'sysBP',
#        'diaBP', 'BMI', 'heartRate', 'glucose', 'TenYearCHD'],
#       dtype='object')

# %%
print(data[['heartRate']].isna().sum())
print(data[['diaBP']].isna().sum())
print(data[['age']].isna().sum())
print(data[['glucose']].isna().sum())
print(data[['totChol']].isna().sum())
print(data[['BMI']].isna().sum())
print(data[['sysBP']].isna().sum())
# Out:
# heartRate    1
# dtype: int64
# diaBP    0
# dtype: int64
# age    0
# dtype: int64
# glucose    388
# dtype: int64
# totChol    50
# dtype: int64
# BMI    19
# dtype: int64
# sysBP    0
# dtype: int64

# %%
column_names = ['heartRate', 'glucose', 'totChol', 'BMI']

for i in range(len(column_names)):
    column_mean = data[column_names[i]].mean()
    data[column_names[i]].fillna(column_mean, inplace=True)

# %%
print(data[['heartRate']].isna().sum())
print(data[['diaBP']].isna().sum())
print(data[['age']].isna().sum())
print(data[['glucose']].isna().sum())
print(data[['totChol']].isna().sum())
print(data[['BMI']].isna().sum())
print(data[['sysBP']].isna().sum())
# Out:
# heartRate    0
# dtype: int64
# diaBP    0
# dtype: int64
# age    0
# dtype: int64
# glucose    0
# dtype: int64
# totChol    0
# dtype: int64
# BMI    0
# dtype: int64
# sysBP    0
# dtype: int64

# %%
x= data[['heartRate','diaBP','age','glucose','totChol','BMI','sysBP']] 
y= data.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split  

x_train, x_test, y_train, y_test= train_test_split(x, y, test_size= 0.25, random_state=0)

# %%
x_train
# Out:
#       heartRate  diaBP  age  glucose  totChol    BMI  sysBP
# 3748       66.0   74.0   60     85.0    275.0  19.91  134.0
# 1928       95.0   91.5   42     74.0    193.0  27.78  129.0
# 2058       75.0   75.0   60     98.0    305.0  22.70  112.5
# 2106       65.0   83.0   67     78.0    250.0  22.36  120.0
# 3103       80.0   71.0   51     84.0    236.0  23.48  115.0
# ...         ...    ...  ...      ...      ...    ...    ...
# 1033       85.0   83.0   44     75.0    187.0  30.40  122.0
# 3264       75.0   81.0   51     96.0    261.0  20.24  127.0
# 1653       70.0   62.0   39     81.0    148.0  24.47  101.0
# 2607       75.0   77.0   57     81.0    382.0  24.27  133.0
# 2732       75.0   92.0   40     73.0    232.0  26.56  140.0
#
# [3178 rows x 7 columns]

# %%
#feature Scaling  
from sklearn.preprocessing import StandardScaler    
st_scaler= StandardScaler()    
x_train= st_scaler.fit_transform(x_train)    
x_test= st_scaler.transform(x_test)

# %%
x_train
# Out:
# array([[-0.81568787, -0.73456254,  1.21793504, ...,  0.85953118,
#         -1.44678609,  0.08630757],
#        [ 1.59216957,  0.73697033, -0.88304973, ..., -1.01201542,
#          0.48838803, -0.14297059],
#        [-0.06842177, -0.65047494,  1.21793504, ...,  1.54424336,
#         -0.76074597, -0.89958851],
#        ...,
#        [-0.48356961, -1.74361365, -1.23321386, ..., -2.03908368,
#         -0.32551621, -1.42692827],
#        [-0.06842177, -0.48229976,  0.86777091, ...,  3.30167126,
#         -0.37469471,  0.04045194],
#        [-0.06842177,  0.77901413, -1.11649249, ..., -0.1218896 ,
#          0.18839915,  0.36144136]])

# %%
y_train
# Out:
# 3748    0
# 1928    0
# 2058    1
# 2106    1
# 3103    0
#        ..
# 1033    0
# 3264    0
# 1653    0
# 2607    0
# 2732    0
# Name: TenYearCHD, Length: 3178, dtype: int64

# %%
#Fitting Logistic Regression to the training set  
from sklearn.linear_model import LogisticRegression  
log_reg= LogisticRegression(random_state=0)  
log_reg.fit(x_train, y_train)
# Out:
# LogisticRegression(random_state=0)

# %%
y_pred = log_reg.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix  
con_mx = confusion_matrix(y_test, y_pred) 
con_mx
# Out:
# array([[882,   8],
#        [165,   5]])

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score

accuracy = accuracy_score(y_test , y_pred)
print("The accuracy = ",accuracy,"\n")
print("Precision_score :",precision_score(y_test, y_pred)*100,"\n")
print("Recall_score :", recall_score(y_test, y_pred)*100,"\n")
# Out:
# The accuracy =  0.8367924528301887
#
# Precision_score : 38.46153846153847
#
# Recall_score : 2.941176470588235
